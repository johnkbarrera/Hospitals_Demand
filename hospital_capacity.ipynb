# %%
from dask.distributed import Client
client = Client(n_workers=20, threads_per_worker=4, processes=True, memory_limit='50GB')
client
# Out:
# <Client: 'tcp://127.0.0.1:41281' processes=20 threads=80, memory=0.91 TiB>

# %%
import dask.dataframe as dd

# %%
df = dd.read_csv('data/morbilidad_global_ts.csv', blocksize=50e6)

# %%
df.dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-b959c06452a1> in <module>
# ----> 1 df.dtype
#
# ~/.conda/envs/graph_work/lib/python3.7/site-packages/dask/dataframe/core.py in __getattr__(self, key)
#    4148             return self[key]
#    4149         else:
# -> 4150             raise AttributeError("'DataFrame' object has no attribute %r" % key)
#    4151
#    4152     def __dir__(self):
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'
